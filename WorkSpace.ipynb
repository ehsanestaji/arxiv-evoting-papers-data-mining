# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('Final Collected Lists')

# %%
df.head()
# Out:
#   container_type                                              title  \
# 0    Publication  Elderly electors go postal: Ensuring absentee ...
# 1    Publication               Absentee voting in the United States
# 2    Publication  Absentee and Write-In Ballots: Constitutional ...
# 3    Publication        Georgia: 2020 Election Policies & Practices
# 4    Publication  The Absentee Ballot and the Secret Ballot: Cha...
#
#                                        author  pub_year  \
# 0                                  ['JA Fay']    2005.0
# 1                          ['PG Steinbicker']    1938.0
# 2                              ['RE Hawkins']    2012.0
# 3  ['B Baccaglini', 'SR Rates', 'CA Ballots']    2020.0
# 4               ['JC Fortier', 'NJ Ornstein']    2002.0
#
#                                venue  \
# 0                           Elder LJ
# 1  American Political Science Review
# 2      CANADIAN PARLIAMENTARY REVIEW
# 3                  HealthyElection …
# ...

# %% [markdown]
# ## Excluding the papers which are not in the related fields

# %%
df[['title','abstract']].head()
# Out:
#                                                title  \
# 0  Elderly electors go postal: Ensuring absentee ...
# 1               Absentee voting in the United States
# 2  Absentee and Write-In Ballots: Constitutional ...
# 3        Georgia: 2020 Election Policies & Practices
# 4  The Absentee Ballot and the Secret Ballot: Cha...
#
#                                             abstract
# 0  popularity of absentee voting among electors n...
# 1  In any cases in which the affidavit is not suf...
# 2  to cast an absentee ballot must apply to be pl...
# 3  or mark on the absentee elector’s voter regist...
# 4  The court held that absentee voter laws were c...

# %%
"""
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()

"""
# Out:
# '\nimport nltk\nimport ssl\n\ntry:\n    _create_unverified_https_context = ssl._create_unverified_context\nexcept AttributeError:\n    pass\nelse:\n    ssl._create_default_https_context = _create_unverified_https_context\n\nnltk.download()\n\n'

# %%
import pandas as pd
import nltk
import string
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk import word_tokenize
from gensim.models import Word2Vec as w2v
from sklearn.decomposition import PCA

# constants
sw = stopwords.words('english')
plt.style.use('ggplot')


from nltk.tokenize import word_tokenize

# %%
text = df['abstract'].loc[0]

# %%
text.rstrip()
# Out:
# 'popularity of absentee voting among electors nationwide, the process of absentee balloting  has  The recent upsurge in popularity of absentee voting has highlighted the corresponding'

# %%
text_token = word_tokenize(text)
text_token_remove_stopword = [w for w in text_token if w not in sw]
text_token_remove_stopword
# Out:
# ['popularity',
#  'absentee',
#  'voting',
#  'among',
#  'electors',
#  'nationwide',
#  ',',
#  'process',
#  'absentee',
#  'balloting',
#  'The',
#  'recent',
#  'upsurge',
#  'popularity',
#  'absentee',
#  'voting',
#  'highlighted',
#  'corresponding']

# %%
corpus = df.abstract.values

# %%
from gensim.corpora import Dictionary
from gensim.models import ldamodel
import numpy
# %matplotlib inline

import logging
logging.basicConfig(level=logging.INFO)


import collections
from gensim.parsing.preprocessing import preprocess_string

# %%
preprocess_string(corpus[3])
# Out:
# ['mark',
#  'absente',
#  'elector’',
#  'voter',
#  'registr',
#  'card',
#  'recent',
#  'updat',
#  'absente',
#  'elector’',
#  'voter',
#  'registr',
#  'card',
#  'applic',
#  'absente',
#  'ballot',
#  'facsimil']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy

import seaborn as sns
import spacy
spacy.load("en_core_web_sm")
sns.set()
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()# Visualise inside a notebook
#import en_core_web_md
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel


reports =df

reports = reports.astype('str')

nlp = spacy.load("en_core_web_sm")
removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
tokens = []
for summary in nlp.pipe(reports['abstract']):
    proj_tok = [token.lemma_.lower() for token in summary if token.pos_ not in removal and not token.is_stop and token.is_alpha]
    tokens.append(proj_tok)
    

reports['tokens'] = tokens
reports['tokens']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0        [popularity, absentee, voting, elector, proces...
# 1        [case, affidavit, sufficient, signature, corre...
# 2        [cast, absentee, ballot, apply, place, registe...
# 3        [mark, absentee, elector, voter, registration,...
# 4        [court, hold, absentee, voter, law, constituti...
#                                ...
# 10030    [background, patient, stable, coronary, diseas...
# 10031    [biological, control, project, succeed, contai...
# 10032    [uncertain, specific, indication, test, accept...
# 10033                                                [nan]
# ...

# %%
dictionary = Dictionary(reports['tokens'])
print(dictionary.token2id)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary<0 unique tokens: []>
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary<13085 unique tokens: ['absentee', 'balloting', 'corresponding', 'elector', 'highlight']...>
# INFO:gensim.corpora.dictionary:built Dictionary<13124 unique tokens: ['absentee', 'balloting', 'corresponding', 'elector', 'highlight']...> from 10035 documents (total 148798 corpus positions)
# ...

# %%
#!pip install spacy
#!pip install pyLDAvis
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=1000)
corpus = [dictionary.doc2bow(doc) for doc in reports['tokens']]
corpus
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:gensim.corpora.dictionary:discarding 12124 tokens: [('corresponding', 10), ('highlight', 21), ('popularity', 6), ('upsurge', 1), ('affidavit', 10), ('evident', 7), ('qualified', 22), ('sufficient', 22), ('electors', 1), ('ontario', 2)]...
# INFO:gensim.corpora.dictionary:keeping 1000 tokens which were in no less than 5 and no more than 5017 (=50.0%) documents
# INFO:gensim.corpora.dictionary:resulting dictionary: Dictionary<1000 unique tokens: ['absentee', 'balloting', 'elector', 'process', 'recent']...>
# [[(0, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2)],
# ...

# %%
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=10, workers = 4, passes=100)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.1
# INFO:gensim.models.ldamodel:using symmetric eta at 0.1
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running online LDA training, 10 topics, 100 passes over the supplied corpus of 10035 documents, updating every 8000 documents, evaluating every ~10035 documents, iterating 100x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 4 processes
# ...

# %%
lda_model.print_topics(-1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO:gensim.models.ldamodel:topic #0 (0.100): 0.037*"method" + 0.025*"study" + 0.015*"good" + 0.015*"democracy" + 0.014*"condorcet" + 0.014*"usability" + 0.013*"model" + 0.013*"non" + 0.012*"use" + 0.012*"criterion"
# INFO:gensim.models.ldamodel:topic #1 (0.100): 0.026*"quota" + 0.021*"verifiability" + 0.018*"large" + 0.018*"level" + 0.017*"datum" + 0.017*"social" + 0.016*"universal" + 0.015*"risk" + 0.013*"limit" + 0.013*"article"
# ...

# %%
reports['abstract'][0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'popularity of absentee voting among electors nationwide, the process of absentee balloting  has  The recent upsurge in popularity of absentee voting has highlighted the corresponding'

# %%
lda_model[corpus][100]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(4, 0.23440585), (8, 0.7040323)]

# %%
reports['abstract'][100]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'created by the electoral system (ie, proximal effects). Electoral system explanations are  less convincing when they require multiple steps to get from the electoral rule incentives to the'

# %%
reports
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 0        Publication  Elderly electors go postal: Ensuring absentee ...
# 1        Publication               Absentee voting in the United States
# 2        Publication  Absentee and Write-In Ballots: Constitutional ...
# 3        Publication        Georgia: 2020 Election Policies & Practices
# 4        Publication  The Absentee Ballot and the Secret Ballot: Cha...
# ...              ...                                                ...
# 10030    Publication  Initial invasive or conservative strategy for ...
# ...

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el172301406915378704002437626355"></div>
# <script type="text/javascript">
#
# ...

# %%
reports['topic'] = [sorted(lda_model[corpus][text])[0][0] for text in range(len(reports['abstract']))]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reports.topic.value_counts()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0    5546
# 3    1268
# 1    1062
# 2     951
# 4     467
# 6     222
# 7     207
# 8     110
# 5     102
# 9     100
# Name: topic, dtype: int64

# %%
lda_model[corpus][0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0, 0.91901755),
#  (1, 0.020094898),
#  (2, 0.02011357),
#  (3, 0.020185342),
#  (4, 0.02058869)]

# %%
corpus[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2)]

# %%
reports.iloc[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# container_type                                          Publication
# title             Elderly electors go postal: Ensuring absentee ...
# author                                                   ['JA Fay']
# pub_year                                                     2005.0
# venue                                                      Elder LJ
# abstract          popularity of absentee voting among electors n...
# author_id                                                      ['']
# num_citations                                                    30
# ...

# %%
dictionary
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reports['abstract'][0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'popularity of absentee voting among electors nationwide, the process of absentee balloting  has  The recent upsurge in popularity of absentee voting has highlighted the corresponding'

# %%
corpus[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2)]

# %%
corpus[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2)]

# %%
reports
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 0        Publication  Elderly electors go postal: Ensuring absentee ...
# 1        Publication               Absentee voting in the United States
# 2        Publication  Absentee and Write-In Ballots: Constitutional ...
# 3        Publication        Georgia: 2020 Election Policies & Practices
# 4        Publication  The Absentee Ballot and the Secret Ballot: Cha...
# ...              ...                                                ...
# 10030    Publication  Initial invasive or conservative strategy for ...
# ...

# %%
reports[reports['topic'] == 2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 34       Publication  Second price auctions on general preference do...
# 132      Publication  E-NOTE: An E-voting system that ensures voter ...
# 151      Publication  Three voting protocols: ThreeBallot, VAV, and ...
# 152      Publication  A three-ballot-based secure electronic voting ...
# 153      Publication  Bisimulations for verifying strategic abilitie...
# ...              ...                                                ...
# 9967     Publication  Election verifiability: cryptographic definiti...
# ...

# %%
reports.sort_values(by = 'num_citations', ascending= False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      container_type                                              title  \
# 8128    Publication              Electoral systems and public spending
# 7530    Publication                                    Social cohesion
# 2871    Publication     SOME THOUGHTS ON NUTRIENT LIMITATION IN ALGAE1
# 2748    Publication                       Condorcet's theory of voting
# 4225    Publication  Commercial-off-the-shelf games in the digital ...
# ...             ...                                                ...
# 1563    Publication  Oversight Hearing on the Election Assistance C...
# ...

# %%
reports['venue'].value_counts()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# nan                                                  1844
# Electoral Studies                                     178
# EVT                                                    84
# Cryptology ePrint Archive                              71
# American Journal of Political Science                  65
#                                                      ...
# Australian Mammalogy                                    1
# International journal of management and applied …       1
# Journal of Political …                                  1
# Social psychology: Handbook of basic principles         1
# ...

# %%
int(2.0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2

# %%
a = reports.pub_year[0]
a
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '2005.0'

# %%
import math
math.trunc(a)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-53fa1ccf5281> in <module>
#       1 import math
# ----> 2 math.trunc(a)
#
# TypeError: type str doesn't define __trunc__ method

# %%
import math

math.trunc(-10.90)
# Returns -10
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -10

# %%
int(str.split(a,'.')[0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2005

# %%
reports.pub_year.apply(lambda x: int(str.split(x,'.')[0]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-e9668a2d1860> in <module>
# ----> 1 reports.pub_year.apply(lambda x: int(str.split(x,'.')[0]))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
# ...

# %%
(reports.pub_year == 'nan').sum()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 557

# %%
import numpy as np
type(np)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# module

# %%
np.NaN
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# nan

# %%
type(np.NaN)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# float

# %% [markdown]
# # Data Analysis : pub_year columns and its relation with num_citations

# %%
(reports== 'nan').sum()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# container_type       0
# title                0
# author               0
# pub_year           557
# venue             1844
# abstract           446
# author_id            0
# num_citations        0
# tokens               0
# topic                0
# dtype: int64

# %%
reports.pub_year.astype('float').astype('int')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-c89fc511ac89> in <module>
# ----> 1 reports.pub_year.astype('float').astype('int')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 11       Publication  Brannon v. City of Coeur d'Alene Appellant's R...
# 88       Publication  Eligibility Verifiability in Untrustworthy Vot...
# 139      Publication  Determining the Causes of AccuVote Optical Sca...
# 142      Publication              reference, Archive Date Oct. 12, 1999
# 144      Publication  Trusted agent report: Diebold AccuVote-TS voti...
# ...              ...                                                ...
# 9977     Publication  ICNSCET19-International Conference on New Scie...
# ...

# %%
reports.iloc[reports[reports['pub_year'] != 'nan'].index]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 0        Publication  Elderly electors go postal: Ensuring absentee ...
# 1        Publication               Absentee voting in the United States
# 2        Publication  Absentee and Write-In Ballots: Constitutional ...
# 3        Publication        Georgia: 2020 Election Policies & Practices
# 4        Publication  The Absentee Ballot and the Secret Ballot: Cha...
# ...              ...                                                ...
# 10029    Publication  Trademark Examining Operation-At Your Service ...
# ...

# %%
list(map(math.trunc, reports['pub_year'].astype('float')))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-0fa5feebcd1f> in <module>
# ----> 1 list(map(math.trunc, reports['pub_year'].astype('float')))
#
# ValueError: cannot convert float NaN to integer

# %%
reports.iloc[reports[reports['pub_year'] != 'nan'].index]['pub_year'] = list(map(math.trunc, reports.iloc[reports[reports['pub_year'] != 'nan'].index]['pub_year'].astype('float')))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reports
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 0        Publication  Elderly electors go postal: Ensuring absentee ...
# 1        Publication               Absentee voting in the United States
# 2        Publication  Absentee and Write-In Ballots: Constitutional ...
# 3        Publication        Georgia: 2020 Election Policies & Practices
# 4        Publication  The Absentee Ballot and the Secret Ballot: Cha...
# ...              ...                                                ...
# 10030    Publication  Initial invasive or conservative strategy for ...
# ...

# %%
reports[reports['abstract'] == 'nan']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       container_type                                              title  \
# 41       Publication  The Desirable Mechanism for Review of the Gove...
# 142      Publication              reference, Archive Date Oct. 12, 1999
# 143      Publication  Trusted agent report Diebold AccuVote-TS votin...
# 144      Publication  Trusted agent report: Diebold AccuVote-TS voti...
# 145      Publication  Trusted agent report Diebold AccuVote-TS votin...
# ...              ...                                                ...
# 9944     Publication                         306 Eco Canvass Award 2008
# ...
